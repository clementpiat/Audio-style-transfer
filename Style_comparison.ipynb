# %%
## run twice

import soundfile as sf
import IPython.display as ipd
import matplotlib.pyplot as plt
from scipy import signal
import numpy as np


genres=['blues','classical','country','disco','hiphop','jazz','metal','pop','reggae','rock']
fig=plt.figure(figsize=(30, 30))
i=0
for genre in genres:

    for j in range(4):
        tmp="/home/clementp/INNO/genres/"+genre+"/"+genre+".0001"+str(j)+".au"
        x, fs = sf.read(tmp)
        x=x[:int(x.shape[0]*0.1)]
        ipd.Audio(x,rate=fs)
        t, f,Zxx = signal.stft(x, fs=fs, nperseg=512)
        module=(abs(Zxx)**2)*2500
        module=module[:128,:]
        result=np.stack([module,module,module], axis=-1)
        fig.add_subplot(10,4,i*4+j+1)
        plt.imshow(result)
    i+=1
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
import soundfile as sf
import IPython.display as ipd
import matplotlib.pyplot as plt
from scipy import signal
import numpy as np


genres=['blues','classical','country','disco','hiphop','jazz','metal','pop','reggae','rock']
fig=plt.figure(figsize=(30, 30))
i=0
for genre in genres:
    modules=[]
    for j in range(10):
        tmp="/home/clementp/INNO/genres/"+genre+"/"+genre+".0001"+str(j)+".au"
        x, fs = sf.read(tmp)
        x=x[:int(x.shape[0]*0.1)]
        ipd.Audio(x,rate=fs)
        t, f,Zxx = signal.stft(x, fs=fs, nperseg=512)
        module=(abs(Zxx)**2)*2500
        module=module[:128,:]
        modules.append(module)
    module=modules[0][:128,:160]
    for j in range(1,len(modules)):
        module+=modules[j][:128,:160]
    
    module=module/10
    result=np.stack([module,module,module], axis=-1)
    fig.add_subplot(10,4,i*4+1)
    plt.imshow(result)
    
    
    i+=1
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
import soundfile as sf
import IPython.display as ipd
import matplotlib.pyplot as plt
from scipy import signal
import numpy as np


genres=['blues','classical','country','disco','hiphop','jazz','metal','pop','reggae','rock']
fig=plt.figure(figsize=(30, 30))
i=0
for genre in genres:
    modules=[]
    for j in range(10):
        tmp="/home/clementp/INNO/genres/"+genre+"/"+genre+".0001"+str(j)+".au"
        x, fs = sf.read(tmp)
        x=x[:int(x.shape[0]*0.1)]
        ipd.Audio(x,rate=fs)
        t, f,Zxx = signal.stft(x, fs=fs, nperseg=512)
        module=(abs(Zxx)**2)*2500
        module=module[:128,:]
        modules.append(module)
    for j in range(10,100):
        tmp="/home/clementp/INNO/genres/"+genre+"/"+genre+".000"+str(j)+".au"
        x, fs = sf.read(tmp)
        x=x[:int(x.shape[0]*0.1)]
        ipd.Audio(x,rate=fs)
        t, f,Zxx = signal.stft(x, fs=fs, nperseg=512)
        module=(abs(Zxx)**2)*2500
        module=module[:128,:]
        modules.append(module)
    module=modules[0][:128,:160]
    for j in range(1,len(modules)):
        module+=modules[j][:128,:160]
    
    module=module/100
    result=np.stack([module,module,module], axis=-1)
    fig.add_subplot(10,4,i*4+1)
    plt.imshow(result)
    
    
    i+=1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-af5cfe8b6284> in <module>()
#      15         tmp="/home/clementp/INNO/genres/"+genre+"/"+genre+".0001"+str(j)+".au"
#      16         x, fs = sf.read(tmp)
# ---> 17         x=x[:int(x.shape[10]*0.1)]
#      18         ipd.Audio(x,rate=fs)
#      19         t, f,Zxx = signal.stft(x, fs=fs, nperseg=512)
#
# IndexError: tuple index out of range
